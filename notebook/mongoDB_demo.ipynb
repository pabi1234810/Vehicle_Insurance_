# %%
import sys
# !{sys.executable} -m pip install pandas
import sys, importlib, subprocess
print("sys.executable:", sys.executable)
print("sys.version:", sys.version)
print("importlib.util.find_spec('pandas'):", importlib.util.find_spec("pandas"))
import pandas as pd
import pymongo

df = pd.read_csv('data.csv')
df.head()
# Out:
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\chakr\anaconda3\envs\vehicle\Lib\site-packages\pip\__main__.py", line 24, in <module>
#     sys.exit(_main())
#              ^^^^^^^
#   File "c:\Users\chakr\anaconda3\envs\vehicle\Lib\site-packages\pip\_internal\cli\main.py", line 78, in main
#     command = create_command(cmd_name, isolated=("--isolated" in cmd_args))
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\chakr\anaconda3\envs\vehicle\Lib\site-packages\pip\_internal\commands\__init__.py", line 121, in create_command
#     module = importlib.import_module(module_path)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\chakr\anaconda3\envs\vehicle\Lib\importlib\__init__.py", line 90, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1387, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1331, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 935, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 995, in exec_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "c:\Users\chakr\anaconda3\envs\vehicle\Lib\site-packages\pip\_internal\commands\install.py", line 22, in <module>
#     import pip._internal.self_outdated_check  # noqa: F401
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\chakr\anaconda3\envs\vehicle\Lib\site-packages\pip\_internal\self_outdated_check.py", line 20, in <module>
#     from pip._internal.index.collector import LinkCollector
# ModuleNotFoundError: No module named 'pip._internal.index'
# sys.executable: c:\Users\chakr\anaconda3\envs\vehicle\python.exe
# sys.version: 3.12.5 | packaged by Anaconda, Inc. | (main, Sep 12 2024, 18:18:29) [MSC v.1929 64 bit (AMD64)]
# importlib.util.find_spec('pandas'): ModuleSpec(name='pandas', loader=<_frozen_importlib_external.SourceFileLoader object at 0x000001B2D85915B0>, origin='c:\\Users\\chakr\\anaconda3\\envs\\vehicle\\Lib\\site-packages\\pandas\\__init__.py', submodule_search_locations=['c:\\Users\\chakr\\anaconda3\\envs\\vehicle\\Lib\\site-packages\\pandas'])
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %%
pip install pymongo
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\chakr\anaconda3\envs\vehicle\Lib\site-packages\pip\__main__.py", line 24, in <module>
#     sys.exit(_main())
#              ^^^^^^^
#   File "c:\Users\chakr\anaconda3\envs\vehicle\Lib\site-packages\pip\_internal\cli\main.py", line 78, in main
#     command = create_command(cmd_name, isolated=("--isolated" in cmd_args))
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\chakr\anaconda3\envs\vehicle\Lib\site-packages\pip\_internal\commands\__init__.py", line 121, in create_command
#     module = importlib.import_module(module_path)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\chakr\anaconda3\envs\vehicle\Lib\importlib\__init__.py", line 90, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1387, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1331, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 935, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 995, in exec_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "c:\Users\chakr\anaconda3\envs\vehicle\Lib\site-packages\pip\_internal\commands\install.py", line 22, in <module>
#     import pip._internal.self_outdated_check  # noqa: F401
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\chakr\anaconda3\envs\vehicle\Lib\site-packages\pip\_internal\self_outdated_check.py", line 20, in <module>
#     from pip._internal.index.collector import LinkCollector
# ModuleNotFoundError: No module named 'pip._internal.index'

# %%
df = pd.read_csv('data.csv')
df.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %%
# df should be converted into dict before we push it to mongodb

data = df.to_dict(orient='records')
# data

# %%
DB_NAME = "Proj1"
COLLECTION_NAME = "Proj1-Data"
CONNECTION_URL = "mongodb+srv://Pabitra_10:vrNBEjkGPqZLEjaz@cluster0.htocyri.mongodb.net/?appName=Cluster0"

# %%
import pymongo

# %%
from pymongo import MongoClient

# %%
client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]

# %%
rec = collection.insert_many(data)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 rec = collection.insert_many(data)
#
# File c:\Users\chakr\anaconda3\envs\vehicle\Lib\site-packages\pymongo\_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File c:\Users\chakr\anaconda3\envs\vehicle\Lib\site-packages\pymongo\synchronous\collection.py:975, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     973 blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     974 blk.ops = list(gen())
# --> 975 blk.execute(write_concern, session, _Op.INSERT)
#     976 return InsertManyResult(inserted_ids, write_concern.acknowledged)
#
# File c:\Users\chakr\anaconda3\envs\vehicle\Lib\site-packages\pymongo\synchronous\bulk.py:751, in _Bulk.execute(self, write_concern, session, operation)
#     749         return None
#     750 else:
# --> 751     return self.execute_command(generator, write_concern, session, operation)
#
# File c:\Users\chakr\anaconda3\envs\vehicle\Lib\site-packages\pymongo\synchronous\bulk.py:604, in _Bulk.execute_command(self, generator, write_concern, session, operation)
#     593     self._execute_command(
#     594         generator,
#     595         write_concern,
#    (...)    600         full_result,
#     601     )
#     603 client = self.collection.database.client
# --> 604 _ = client._retryable_write(
#     605     self.is_retryable,
#     606     retryable_bulk,
#     607     session,
#     608     operation,
#     609     bulk=self,  # type: ignore[arg-type]
#     610     operation_id=op_id,
#     611 )
#     613 if full_result["writeErrors"] or full_result["writeConcernErrors"]:
#     614     _raise_bulk_write_error(full_result)
#
# File c:\Users\chakr\anaconda3\envs\vehicle\Lib\site-packages\pymongo\synchronous\mongo_client.py:2083, in MongoClient._retryable_write(self, retryable, func, session, operation, bulk, operation_id)
#    2069 """Execute an operation with consecutive retries if possible
#    2070
#    2071 Returns func()'s return value on success. On error retries the same
#    (...)   2080 :param bulk: bulk abstraction to execute operations in bulk, defaults to None
#    2081 """
#    2082 with self._tmp_session(session) as s:
# -> 2083     return self._retry_with_session(retryable, func, s, bulk, operation, operation_id)
#
# File c:\Users\chakr\anaconda3\envs\vehicle\Lib\site-packages\pymongo\synchronous\mongo_client.py:1968, in MongoClient._retry_with_session(self, retryable, func, session, bulk, operation, operation_id)
#    1963 # Ensure that the options supports retry_writes and there is a valid session not in
#    1964 # transaction, otherwise, we will not support retry behavior for this txn.
#    1965 retryable = bool(
#    1966     retryable and self.options.retry_writes and session and not session.in_transaction
#    1967 )
# -> 1968 return self._retry_internal(
#    1969     func=func,
#    1970     session=session,
#    1971     bulk=bulk,
#    1972     operation=operation,
#    1973     retryable=retryable,
#    1974     operation_id=operation_id,
#    1975 )
#
# File c:\Users\chakr\anaconda3\envs\vehicle\Lib\site-packages\pymongo\_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File c:\Users\chakr\anaconda3\envs\vehicle\Lib\site-packages\pymongo\synchronous\mongo_client.py:2014, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1977 @_csot.apply
#    1978 def _retry_internal(
#    1979     self,
#    (...)   1988     operation_id: Optional[int] = None,
#    1989 ) -> T:
#    1990     """Internal retryable helper for all client transactions.
#    1991
#    1992     :param func: Callback function we want to retry
#    (...)   2001     :return: Output of the calling func()
#    2002     """
#    2003     return _ClientConnectionRetryable(
#    2004         mongo_client=self,
#    2005         func=func,
#    2006         bulk=bulk,
#    2007         operation=operation,
#    2008         is_read=is_read,
#    2009         session=session,
#    2010         read_pref=read_pref,
#    2011         address=address,
#    2012         retryable=retryable,
#    2013         operation_id=operation_id,
# -> 2014     ).run()
#
# File c:\Users\chakr\anaconda3\envs\vehicle\Lib\site-packages\pymongo\synchronous\mongo_client.py:2763, in _ClientConnectionRetryable.run(self)
#    2761 self._check_last_error(check_csot=True)
#    2762 try:
# -> 2763     return self._read() if self._is_read else self._write()
#    2764 except ServerSelectionTimeoutError:
#    2765     # The application may think the write was never attempted
#    2766     # if we raise ServerSelectionTimeoutError on the retry
#    2767     # attempt. Raise the original exception instead.
#    2768     self._check_last_error()
#
# File c:\Users\chakr\anaconda3\envs\vehicle\Lib\site-packages\pymongo\synchronous\mongo_client.py:2874, in _ClientConnectionRetryable._write(self)
#    2872 is_mongos = False
#    2873 self._server = self._get_server()
# -> 2874 with self._client._checkout(self._server, self._session) as conn:
#    2875     max_wire_version = conn.max_wire_version
#    2876     sessions_supported = (
#    2877         self._session
#    2878         and self._server.description.retryable_writes_supported
#    2879         and conn.supports_sessions
#    2880     )
#
# File c:\Users\chakr\anaconda3\envs\vehicle\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\chakr\anaconda3\envs\vehicle\Lib\site-packages\pymongo\synchronous\mongo_client.py:1777, in MongoClient._checkout(self, server, session)
#    1775     yield session._pinned_connection
#    1776     return
# -> 1777 with server.checkout(handler=err_handler) as conn:
#    1778     # Pin this session to the selected server or connection.
#    1779     if (
#    1780         in_txn
#    1781         and session
#    (...)   1786         )
#    1787     ):
#    1788         session._pin(server, conn)
#
# File c:\Users\chakr\anaconda3\envs\vehicle\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\chakr\anaconda3\envs\vehicle\Lib\site-packages\pymongo\synchronous\pool.py:1101, in Pool.checkout(self, handler)
#    1092 if self.enabled_for_logging and _CONNECTION_LOGGER.isEnabledFor(logging.DEBUG):
#    1093     _debug_log(
#    1094         _CONNECTION_LOGGER,
#    1095         message=_ConnectionStatusMessage.CHECKOUT_STARTED,
#    (...)   1098         serverPort=self.address[1],
#    1099     )
# -> 1101 conn = self._get_conn(checkout_started_time, handler=handler)
#    1103 duration = time.monotonic() - checkout_started_time
#    1104 if self.enabled_for_cmap:
#
# File c:\Users\chakr\anaconda3\envs\vehicle\Lib\site-packages\pymongo\synchronous\pool.py:1263, in Pool._get_conn(self, checkout_started_time, handler)
#    1261 else:  # We need to create a new connection
#    1262     try:
# -> 1263         conn = self.connect(handler=handler)
#    1264     finally:
#    1265         with self._max_connecting_cond:
#
# File c:\Users\chakr\anaconda3\envs\vehicle\Lib\site-packages\pymongo\synchronous\pool.py:1055, in Pool.connect(self, handler)
#    1052     if handler:
#    1053         handler.contribute_socket(conn, completed_handshake=False)
# -> 1055     conn.authenticate()
#    1056 # Catch KeyboardInterrupt, CancelledError, etc. and cleanup.
#    1057 except BaseException:
#
# File c:\Users\chakr\anaconda3\envs\vehicle\Lib\site-packages\pymongo\synchronous\pool.py:510, in Connection.authenticate(self, reauthenticate)
#     507 if creds:
#     508     from pymongo.synchronous import auth
# --> 510     auth.authenticate(creds, self, reauthenticate=reauthenticate)
#     511 self.ready = True
#     512 duration = time.monotonic() - self.creation_time
#
# File c:\Users\chakr\anaconda3\envs\vehicle\Lib\site-packages\pymongo\synchronous\auth.py:450, in authenticate(credentials, conn, reauthenticate)
#     448     _authenticate_oidc(credentials, conn, reauthenticate)
#     449 else:
# --> 450     auth_func(credentials, conn)
#
# File c:\Users\chakr\anaconda3\envs\vehicle\Lib\site-packages\pymongo\synchronous\auth.py:355, in _authenticate_default(credentials, conn)
#     353         return _authenticate_scram(credentials, conn, "SCRAM-SHA-256")
#     354     else:
# --> 355         return _authenticate_scram(credentials, conn, "SCRAM-SHA-1")
#     356 else:
#     357     return _authenticate_scram(credentials, conn, "SCRAM-SHA-1")
#
# File c:\Users\chakr\anaconda3\envs\vehicle\Lib\site-packages\pymongo\synchronous\auth.py:96, in _authenticate_scram(credentials, conn, mechanism)
#      94 else:
#      95     nonce, first_bare, cmd = _authenticate_scram_start(credentials, mechanism)
# ---> 96     res = conn.command(source, cmd)
#      98 assert res is not None
#      99 server_first = res["payload"]
#
# File c:\Users\chakr\anaconda3\envs\vehicle\Lib\site-packages\pymongo\synchronous\helpers.py:47, in _handle_reauth.<locals>.inner(*args, **kwargs)
#      44 from pymongo.synchronous.pool import Connection
#      46 try:
# ---> 47     return func(*args, **kwargs)
#      48 except OperationFailure as exc:
#      49     if no_reauth:
#
# File c:\Users\chakr\anaconda3\envs\vehicle\Lib\site-packages\pymongo\synchronous\pool.py:398, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     396     self._raise_if_not_writable(unacknowledged)
#     397 try:
# --> 398     return command(
#     399         self,
#     400         dbname,
#     401         spec,
#     402         self.is_mongos,
#     403         read_preference,
#     404         codec_options,  # type: ignore[arg-type]
#     405         session,
#     406         client,
#     407         check,
#     408         allowable_errors,
#     409         self.address,
#     410         listeners,
#     411         self.max_bson_size,
#     412         read_concern,
#     413         parse_write_concern_error=parse_write_concern_error,
#     414         collation=collation,
#     415         compression_ctx=self.compression_context,
#     416         use_op_msg=self.op_msg_enabled,
#     417         unacknowledged=unacknowledged,
#     418         user_fields=user_fields,
#     419         exhaust_allowed=exhaust_allowed,
#     420         write_concern=write_concern,
#     421     )
#     422 except (OperationFailure, NotPrimaryError):
#     423     raise
#
# File c:\Users\chakr\anaconda3\envs\vehicle\Lib\site-packages\pymongo\synchronous\network.py:212, in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     210             client._process_response(response_doc, session)
#     211         if check:
# --> 212             helpers_shared._check_command_response(
#     213                 response_doc,
#     214                 conn.max_wire_version,
#     215                 allowable_errors,
#     216                 parse_write_concern_error=parse_write_concern_error,
#     217             )
#     218 except Exception as exc:
#     219     duration = datetime.datetime.now() - start
#
# File c:\Users\chakr\anaconda3\envs\vehicle\Lib\site-packages\pymongo\helpers_shared.py:284, in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error, pool_opts)
#     281 elif code == 43:
#     282     raise CursorNotFound(errmsg, code, response, max_wire_version)
# --> 284 raise OperationFailure(errmsg, code, response, max_wire_version)
#
# OperationFailure: bad auth : Authentication failed., full error: {'ok': 0, 'errmsg': 'bad auth : Authentication failed.', 'code': 8000, 'codeName': 'AtlasError'}

# %%
# Load back data from mongodb

df = pd.DataFrame(list(collection.find()))
df.head(2)
# Out:
#                         _id  id Gender  Age  Driving_License  Region_Code  \
# 0  698390f42878b5eefc1e185a   1   Male   44                1         28.0
# 1  698390f42878b5eefc1e185b   2   Male   76                1          3.0
#
#    Previously_Insured Vehicle_Age Vehicle_Damage  Annual_Premium  \
# 0                   0   > 2 Years            Yes         40454.0
# 1                   0    1-2 Year             No         33536.0
#
#    Policy_Sales_Channel  Vintage  Response
# 0                  26.0      217         1
# 1                  26.0      183         0

# %%
## If you are getting timeout issue

# import certifi
# client = pymongo.MongoClient(CONNECTION_URL, tlsCAFile=certifi.where())
# # TO CREATE THE DATABASE
# data_base = client[DB_NAME]
# collection = data_base[COLLECTION_NAME]
# # TO INSERT DATA INTO THE COLLECTION
# rec = collection.insert_many(data)
